# %%
#Importing the Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading The Data Present in Csv file
d=pd.read_csv("C:\\Users\\kumar\\Desktop\\Hamoye\\Task A\\FoodBalanceSheets_E_Africa_NOFLAG.csv",  encoding='latin-1')

# %%
#Converting the Data into DataFrame
data1=pd.DataFrame(d)

# %%
#Displaying the Data
data1
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
#Finding the Sum of all the nulls present in the column
data1.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
#Replacing Null value of a column to a Mode of that column
data1=data1.fillna({"Y2014":data1['Y2014'].mode()[0]})
data1=data1.fillna({"Y2015":data1['Y2015'].mode()[0]})
data1=data1.fillna({"Y2016":data1['Y2016'].mode()[0]})
data1=data1.fillna({"Y2017":data1['Y2017'].mode()[0]})
data1=data1.fillna({"Y2018":data1['Y2018'].mode()[0]})

# %%
#There in no null value left in the Dataset
data1.isnull().sum()
# Out:
# Area Code       0
# Area            0
# Item Code       0
# Item            0
# Element Code    0
# Element         0
# Unit            0
# Y2014           0
# Y2015           0
# Y2016           0
# Y2017           0
# Y2018           0
# dtype: int64

# %%
data1.head(5)
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
#Describing the Dataset
data1.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   60943.000000
# ...

# %% [markdown]
#  What is the mean and standard deviation across the whole dataset for the year 2015 to 3 decimal places?
#
# Ans: 131.800 and 1583.051 respectively

# %%
#Checking if any duplicate element present 
data1.duplicated().any()
# Out:
# False

# %%
n=data1['Area'].unique()
len(n)
# Out:
# 49

# %% [markdown]
# What is the total number of unique countries in the dataset?
#
# Ans=49

# %%
data=data1.groupby('Item')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum();
# Out:
# <ipython-input-12-f2a0ef2cf048>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data=data1.groupby('Item')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum();

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option('display.max_rows', None)

# %%
data
# Out:
#                                       Y2014       Y2015       Y2016  \
# Item
# Alcohol, Non-Food                   2403.00     2180.00     2223.00
# Alcoholic Beverages               102410.11    98783.72    96958.75
# Animal Products                    11935.65    11811.73    11661.69
# Animal fats                       209460.54   200675.72   183314.22
# Apples and products                 9499.23    10559.15     9853.26
# Aquatic Animals, Others               14.55        9.26        6.17
# Aquatic Plants                       507.29      631.23      470.21
# Aquatic Products, Other              519.62      638.42      475.08
# Bananas                            53267.31    55046.76    54376.07
# Barley and products                25384.66    29153.44    24706.08
# Beans                              19207.68    20315.77    19037.50
# Beer                               41879.92    42053.67    42540.48
# Beverages, Alcoholic                3067.16     2818.38     2834.92
# ...

# %% [markdown]
# What is the total sum of Animal Fat produced in 2014 and 2017 respectively?
#
# Ans: 209460.54 and 269617.53 respectively

# %%
data3=data1.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
# Out:
# <ipython-input-16-48fe2ba6a262>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data3=data1.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()

# %%
data3
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %% [markdown]
# Which year had the highest correlation with ‘Element Code’?
#
# Ans : 2017
#
# What is the total number of the sum of Production in 2014?
#
# Ans:1931287.75
#
# Which of these elements had the highest sum in 2018?
#
# Ans: Domestic supply quantity

# %%
data3['Y2018'].sort_values()
# Out:
# Element
# Tourist consumption                            90.00
# Fat supply quantity (g/capita/day)          10258.69
# Protein supply quantity (g/capita/day)      11833.56
# Stock Variation                             20577.91
# Seed                                        25263.14
# Residuals                                   34864.00
# Food supply quantity (kg/capita/yr)         49056.85
# Other uses (non-food)                       91300.97
# Losses                                     163902.00
# Export Quantity                            181594.80
# Feed                                       233489.68
# Import Quantity                            287997.09
# Processing                                 308429.00
# Food supply (kcal/capita/day)              455261.00
# Total Population - Both sexes             1140605.00
# Food                                      1303841.28
# Production                                2075072.89
# Domestic supply quantity                  2161192.10
# ...

# %% [markdown]
# Which of these elements had the 3rd lowest sum in 2018?
#
# Ans:Protein supply quantity (g/capita/day)

# %%
data4=data1.groupby('Area')['Element'].sum()

# %%
data4=data4.to_frame().reset_index()

# %%
data4
# Out:
#                            Area  \
# 0                       Algeria
# 1                        Angola
# 2                         Benin
# 3                      Botswana
# 4                  Burkina Faso
# 5                    Cabo Verde
# 6                      Cameroon
# 7      Central African Republic
# 8                          Chad
# 9                       Comoros
# 10                        Congo
# 11                Côte d'Ivoire
# 12                     Djibouti
# 13                        Egypt
# 14                     Eswatini
# 15                     Ethiopia
# 16                 Ethiopia PDR
# 17                        Gabon
# 18                       Gambia
# 19                        Ghana
# 20                       Guinea
# 21                Guinea-Bissau
# 22                        Kenya
# 23                      Lesotho
# 24                      Liberia
# 25                   Madagascar
# 26                       Malawi
# 27                         Mali
# ...

# %%
#Regression plot between Area and Y2014
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
sns.regplot(x=data1["Area"], y=data1["Y2014"],
fit_reg=False);
plt.title('Plot between Area and Y2014');

# %%
#Regression plot between Area and Y2015
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
sns.regplot(x=data1["Area"], y=data1["Y2015"],
fit_reg=False);
plt.title('Plot between Area and Y2015')
# Out:
# Text(0.5, 1.0, 'Plot between Area and Y2015')

# %%
#Regression plot between Area and Y2016
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
sns.regplot(x=data1["Area"], y=data1["Y2016"],
fit_reg=False);
plt.title('Plot between Area and Y2016')
# Out:
# Text(0.5, 1.0, 'Plot between Area and Y2016')

# %%
#Regression plot between Area and Y2017
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
sns.regplot(x=data1["Area"], y=data1["Y2017"],
fit_reg=False);
plt.title('Plot between Area and Y2017')
# Out:
# Text(0.5, 1.0, 'Plot between Area and Y2017')

# %%
#Regression plot between Area and Y2018
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
sns.regplot(x=data1["Area"], y=data1["Y2018"],
fit_reg=False);
plt.title('Plot between Area and Y2018')
# Out:
# Text(0.5, 1.0, 'Plot between Area and Y2018')

# %%
#Plot Showing Number of Different Area Code Used In Data Set
plt.figure(figsize=(12,6))

plt.xticks(rotation=90)
g = sns.countplot(data=data1, x='Area Code')
plt.title('Number of Different Area Code Used In Data Set')
# Out:
# Text(0.5, 1.0, 'Number of Different Area Code Used In Data Set')

# %%
#Plot Showing Number of Different Element Code Used In Data Set
plt.figure(figsize=(12,6))

plt.xticks(rotation=90)
g = sns.countplot(data=data1, x='Element Code')
plt.title('Number of Different Element Code Used In Data Set')
# Out:
# Text(0.5, 1.0, 'Number of Different Element Code Used In Data Set')

# %%
#Plot Showing Number of Different Area Used In Data Set
plt.figure(figsize=(12,6))

plt.xticks(rotation=90)
g = sns.countplot(data=data1, x='Area')
plt.title('Number of Different Area Used In Data Set')
# Out:
# Text(0.5, 1.0, 'Number of Different Area Used In Data Set')

# %%
#Plot Showing Number of Different Item Used In Data Set
plt.figure(figsize=(18,9))

plt.xticks(rotation=90)
g = sns.countplot(data=data1, x='Item')
plt.title('Number of Different Item Used In Data Set')
# Out:
# Text(0.5, 1.0, 'Number of Different Item Used In Data Set')

# %%
#Different Area Code Occuring in the Y2014
plt.figure(figsize=(12,6))

plt.xticks(rotation=90)
g = sns.barplot(data=data1,x='Area Code',y='Y2014')
plt.title('Number of Different Area Code Occuring In Y2014')
# Out:
# Text(0.5, 1.0, 'Number of Different Area Code Occuring In Y2014')

# %%
#Different Area Code Occuring in the Y2015
plt.figure(figsize=(12,6))

plt.xticks(rotation=90)
g = sns.barplot(data=data1,x='Area Code',y='Y2015')
plt.title('Number of Different Area Code Occuring In Y2015')
# Out:
# Text(0.5, 1.0, 'Number of Different Area Code Occuring In Y2015')

# %%
#Different Area Code Occuring in the Y2016
plt.figure(figsize=(12,6))

plt.xticks(rotation=90)
g = sns.barplot(data=data1,x='Area Code',y='Y2016')
plt.title('Number of Different Area Code Occuring In Y2016')
# Out:
# Text(0.5, 1.0, 'Number of Different Area Code Occuring In Y2016')

# %%
#Different Area Code Occuring in the Y2017
plt.figure(figsize=(12,6))

plt.xticks(rotation=90)
g = sns.barplot(data=data1,x='Area Code',y='Y2017')
plt.title('Number of Different Area Code Occuring In Y2017')
# Out:
# Text(0.5, 1.0, 'Number of Different Area Code Occuring In Y2017')

# %%
#Different Area Code Occuring in the Y2018
plt.figure(figsize=(12,6))

plt.xticks(rotation=90)
g = sns.barplot(data=data1,x='Area Code',y='Y2018')
plt.title('Number of Different Area Code Occuring In Y2018')
# Out:
# Text(0.5, 1.0, 'Number of Different Area Code Occuring In Y2018')

# %%
plt.figure(figsize=(9,6))
sns.heatmap(data1.corr(),annot=True);

# %% [markdown]
# Which year had the highest correlation with ‘Element Code’?
#
# Ans: 2014
